# %% [markdown]
# # Instructor Do: Tone Analysis

# %%
# Initial imports
import os
import json
from dotenv import load_dotenv
from ibm_watson import ToneAnalyzerV3
from pandas import json_normalize
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-c06fbc88e1f4> in <module>
#       4 from dotenv import load_dotenv
#       5 from ibm_watson import ToneAnalyzerV3
# ----> 6 from pandas import json_normalize
#       7 from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
#
# ImportError: cannot import name 'json_normalize' from 'pandas' (C:\Users\user\anaconda3\lib\site-packages\pandas\__init__.py)

# %%
# Out:
# Collecting ibm_watson
#   Downloading ibm-watson-4.5.0.tar.gz (370 kB)
# Requirement already satisfied: requests<3.0,>=2.0 in c:\users\user\anaconda3\lib\site-packages (from ibm_watson) (2.23.0)
# Requirement already satisfied: python_dateutil>=2.5.3 in c:\users\user\anaconda3\lib\site-packages (from ibm_watson) (2.8.1)
# Collecting websocket-client==0.48.0
#   Downloading websocket_client-0.48.0-py2.py3-none-any.whl (198 kB)
# Collecting ibm_cloud_sdk_core==1.5.1
#   Downloading ibm-cloud-sdk-core-1.5.1.tar.gz (25 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm_watson) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm_watson) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm_watson) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.0->ibm_watson) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python_dateutil>=2.5.3->ibm_watson) (1.14.0)
# Collecting PyJWT>=1.7.1
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Building wheels for collected packages: ibm-watson, ibm-cloud-sdk-core
#   Building wheel for ibm-watson (setup.py): started
#   Building wheel for ibm-watson (setup.py): finished with status 'done'
#   Created wheel for ibm-watson: filename=ibm_watson-4.5.0-py3-none-any.whl size=364305 sha256=615717adf233b4ef706f413d6cc32e96c4f3d74c84df8293f9a0ef360ca0102a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\d6\c3\2b\baf31dba99567d020d1111e4d06788d676cd5fc02e2f3b94c1
#   Building wheel for ibm-cloud-sdk-core (setup.py): started
#   Building wheel for ibm-cloud-sdk-core (setup.py): finished with status 'done'
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-1.5.1-py3-none-any.whl size=44493 sha256=323a4c6c9682ad8bf233b1f402392238cb994ee2f32d8b44e4c381a92b215e23
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\51\37\f5\0532ca77cb49d7405e309bb16e3bf3fd4488baabf0f326c63d
# Successfully built ibm-watson ibm-cloud-sdk-core
# Installing collected packages: websocket-client, PyJWT, ibm-cloud-sdk-core, ibm-watson
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.57.0
#     Uninstalling websocket-client-0.57.0:
#       Successfully uninstalled websocket-client-0.57.0
# Successfully installed PyJWT-1.7.1 ibm-cloud-sdk-core-1.5.1 ibm-watson-4.5.0 websocket-client-0.48.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load environment variables and get the Tone Analyzer API Key and URL
load_dotenv()
tone_api = os.getenv("tone_key")
tone_url = os.getenv("tone_url")

# %%
# Initialize Tone Analyser Client

# Create authentication object
authenticator = IAMAuthenticator(tone_api)

# Create tone_analyzer instance
tone_analyzer = ToneAnalyzerV3(
    version="2017-09-21",
    authenticator=authenticator
)

# Set the service endpoint
tone_analyzer.set_service_url(tone_url)

# %% [markdown]
# ## General Tone Analysis Test

# %%
# Define text to analyze
text = """
Team, I know that times are tough!
Product sales have been disappointing for the past three quarters.
We have a competitive product, but we need to do a better job of selling it!
"""

# Analyze the text's tone with the 'tone()' method.
tone_analysis = tone_analyzer.tone(
    {"text": text},
    content_type="application/json",
    content_language="en",
    accept_language="en",
).get_result()

# Display tone analysis results
print(json.dumps(tone_analysis, indent=2))
# Out:
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.6165,
#         "tone_id": "sadness",
#         "tone_name": "Sadness"
#       },
#       {
#         "score": 0.829888,
#         "tone_id": "analytical",
#         "tone_name": "Analytical"
#       }
#     ]
#   },
#   "sentences_tone": [
#     {
#       "sentence_id": 0,
#       "text": "Team, I know that times are tough!",
#       "tones": [
#         {
#           "score": 0.801827,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 1,
#       "text": "Product sales have been disappointing for the past three quarters.",
#       "tones": [
#         {
#           "score": 0.771241,
#           "tone_id": "sadness",
#           "tone_name": "Sadness"
#         },
#         {
#           "score": 0.687768,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 2,
#       "text": "We have a competitive product, but we need to do a better job of selling it!",
#       "tones": [
#         {
#           "score": 0.506763,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ### Transform Tone Analysis json to a DataFrame

# %%
# Document Tones
doc_tone_df = json_normalize(data=tone_analysis["document_tone"], record_path=["tones"])
doc_tone_df
# Out:
#       score     tone_id   tone_name
# 0  0.616500     sadness     Sadness
# 1  0.829888  analytical  Analytical

# %%
# Sentences Tones
sentences_tone_df = json_normalize(
    data=tone_analysis["sentences_tone"],
    record_path=["tones"],
    meta=["sentence_id", "text"],
)
sentences_tone_df
# Out:
#       score     tone_id   tone_name sentence_id  \
# 0  0.801827  analytical  Analytical           0
# 1  0.771241     sadness     Sadness           1
# 2  0.687768  analytical  Analytical           1
# 3  0.506763  analytical  Analytical           2
#
#                                                 text
# 0                 Team, I know that times are tough!
# 1  Product sales have been disappointing for the ...
# 2  Product sales have been disappointing for the ...
# 3  We have a competitive product, but we need to ...

# %% [markdown]
# ## Customer Engagement Tone Analysis

# %%
# Define conversational utterances
utterances = [
    {"text": "Hello, I'm having a problem with your product.", "user": "customer"},
    {"text": "OK, let me know what's going on, please.", "user": "agent"},
    {"text": "Well, nothing is working :(", "user": "customer"},
    {"text": "Sorry to hear that.", "user": "agent"},
]

# Analyze utterances using the 'tone_chat()' method
utterance_analysis = tone_analyzer.tone_chat(
    utterances=utterances, content_language="en", accept_language="en"
).get_result()
print(json.dumps(utterance_analysis, indent=2))
# Out:
# {
#   "utterances_tone": [
#     {
#       "utterance_id": 0,
#       "utterance_text": "Hello, I'm having a problem with your product.",
#       "tones": [
#         {
#           "score": 0.686361,
#           "tone_id": "polite",
#           "tone_name": "Polite"
#         }
#       ]
#     },
#     {
#       "utterance_id": 1,
#       "utterance_text": "OK, let me know what's going on, please.",
#       "tones": [
#         {
#           "score": 0.92724,
#           "tone_id": "polite",
#           "tone_name": "Polite"
#         }
#       ]
#     },
#     {
#       "utterance_id": 2,
#       "utterance_text": "Well, nothing is working :(",
#       "tones": [
#         {
#           "score": 0.997795,
#           "tone_id": "sad",
#           "tone_name": "Sad"
#         }
#       ]
#     },
#     {
#       "utterance_id": 3,
#       "utterance_text": "Sorry to hear that.",
#       "tones": [
#         {
#           "score": 0.730982,
#           "tone_id": "polite",
#           "tone_name": "Polite"
#         },
#         {
#           "score": 0.672499,
#           "tone_id": "sympathetic",
#           "tone_name": "Sympathetic"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ### Transform Chat Analysis json to DataFrame

# %%
# Normalize json structure and import to DataFrame
chat_tone_df = json_normalize(
    data=utterance_analysis["utterances_tone"],
    record_path=["tones"],
    meta=["utterance_id", "utterance_text"],
)
chat_tone_df
# Out:
#       score      tone_id    tone_name utterance_id  \
# 0  0.686361       polite       Polite            0
# 1  0.927240       polite       Polite            1
# 2  0.997795          sad          Sad            2
# 3  0.730982       polite       Polite            3
# 4  0.672499  sympathetic  Sympathetic            3
#
#                                    utterance_text
# 0  Hello, I'm having a problem with your product.
# 1        OK, let me know what's going on, please.
# 2                     Well, nothing is working :(
# 3                             Sorry to hear that.
# 4                             Sorry to hear that.
