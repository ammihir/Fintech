# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Reading the api key environment variable
#load_dotenv("key.env")
api_key = '7d76ce773def40e5bf00fc7213757184'

# %%
# Creating a newsapi client
from newsapi.newsapi_client import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#                    date                                               text  \
# 0  2020-09-10T14:28:00Z  Two alleged crypto traders in Singapore appare...
# 1  2020-09-08T06:02:00Z  By Alexis Akwagyiram, Tom Wilson\r\n* Monthly ...
# 2  2020-08-23T12:19:36Z  “The COVID-19 pandemic has resulted in a mass ...
# 3  2020-09-08T06:34:00Z  LAGOS/LONDON (Reuters) - Four months ago, Abol...
# 4  2020-09-08T06:14:00Z  LAGOS/LONDON (Reuters) - Four months ago, Abol...
#
#    compound  positive  negative  neutral
# 0   -0.6908     0.000      0.16    0.840
# 1    0.0000     0.000      0.00    1.000
# 2    0.2732     0.063      0.00    0.937
# 3    0.0000     0.000      0.00    1.000
# 4    0.0000     0.000      0.00    1.000

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#                    date                                               text  \
# 0  2020-09-02T16:00:00Z  If you've interacted with cryptocurrencies in ...
# 1  2020-09-07T09:04:23Z  TL;DR: The Complete Stock and Cryptocurrency I...
# 2  2020-08-17T04:00:00Z  TL;DR: The Mega Blockchain Mastery Bundle is o...
# 3  2020-08-26T06:07:00Z  LONDON (Reuters) - It sounds like a surefire b...
# 4  2020-08-25T13:01:00Z  NEW YORK (Reuters) - Brooklyn-based technology...
#
#    compound  positive  negative  neutral
# 0    0.7506     0.209       0.0    0.791
# 1    0.0000     0.000       0.0    1.000
# 2    0.0000     0.000       0.0    1.000
# 3    0.7579     0.181       0.0    0.819
# 4    0.0000     0.000       0.0    1.000

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  98.000000  98.000000  98.000000  98.000000
# mean    0.162083   0.077286   0.045286   0.877449
# std     0.456500   0.058448   0.066592   0.075121
# min    -0.865800   0.000000   0.000000   0.588000
# 25%    -0.121675   0.007250   0.000000   0.838500
# 50%     0.273200   0.090000   0.000000   0.884000
# 75%     0.507000   0.120250   0.085000   0.910000
# max     0.790100   0.222000   0.294000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  94.000000  94.000000  94.000000  94.000000
# mean    0.056533   0.060011   0.046223   0.893766
# std     0.429264   0.069236   0.067060   0.086507
# min    -0.910000   0.000000   0.000000   0.689000
# 25%    -0.147275   0.000000   0.000000   0.840250
# 50%     0.000000   0.053500   0.000000   0.909500
# 75%     0.401900   0.089500   0.075000   0.988000
# max     0.851900   0.311000   0.309000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin has a higher score of 0.77
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum has a higher compound score of 0.85
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum has a higher positive score of 0.31

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\daphy\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Complete the tokenizer function

lemmatizer = WordNetLemmatizer()

def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    regex = re.compile("[^a-zA-Z ]")
      
    # Remove the punctuation
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    
    # Remove the stop words
    sw = set(stopwords.words('english'))
    
    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    
    # Convert the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df["tokens"] = bitcoin_df["text"].apply(tokenizer)
bitcoin_df.head()
# Out:
#                    date                                               text  \
# 0  2020-08-06T18:25:29Z  Casa, a Colorado-based provider of bitcoin sec...
# 1  2020-08-03T14:02:34Z  In April, the Secret Service seized 100 Bitcoi...
# 2  2020-08-06T16:16:32Z  The question still remained, though, whether a...
# 3  2020-08-04T20:30:00Z  A ransomware variant called NetWalker is doing...
# 4  2020-08-23T12:19:36Z  “The COVID-19 pandemic has resulted in a mass ...
#
#    compound  positive  negative  neutral  \
# 0    0.5994     0.149     0.000    0.851
# 1    0.0000     0.000     0.000    1.000
# 2   -0.0516     0.065     0.071    0.864
# 3    0.5106     0.122     0.000    0.878
# 4    0.2732     0.063     0.000    0.937
#
#                                               tokens
# 0  [casa, coloradobased, provider, bitcoin, secur...
# 1  [april, secret, service, seized, bitcoins, cla...
# 2  [question, still, remained, though, whether, g...
# 3  [ransomware, variant, called, netwalker, surpr...
# 4  [covid, pandemic, ha, resulted, mass, shift, w...

# %%
# Create a new tokens column for Ethereum
ethereum_df["tokens"] = ethereum_df["text"].apply(tokenizer)
ethereum_df.head()
# Out:
#                    date                                               text  \
# 0  2020-09-02T16:00:00Z  If you've interacted with cryptocurrencies in ...
# 1  2020-08-17T04:00:00Z  TL;DR: The Mega Blockchain Mastery Bundle is o...
# 2  2020-08-26T06:07:00Z  LONDON (Reuters) - It sounds like a surefire b...
# 3  2020-08-25T13:01:00Z  NEW YORK (Reuters) - Brooklyn-based technology...
# 4  2020-08-19T07:04:25Z  An outspoken Bitcoin whale who rarely shows af...
#
#    compound  positive  negative  neutral  \
# 0    0.7506     0.209     0.000    0.791
# 1    0.0000     0.000     0.000    1.000
# 2    0.7579     0.181     0.000    0.819
# 3    0.0000     0.000     0.000    1.000
# 4   -0.2677     0.045     0.074    0.881
#
#                                               tokens
# 0  [youve, interacted, cryptocurrencies, past, co...
# 1  [tldr, mega, blockchain, mastery, bundle, sale...
# 2  [london, reuters, sound, like, surefire, bet, ...
# 3  [new, york, reuters, brooklynbased, technology...
# 4  [outspoken, bitcoin, whale, rarely, show, affe...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_tokens = []
for list in bitcoin_df.tokens:
    bitcoin_tokens += list
    
bitcoin_bigram = Counter(ngrams(bitcoin_tokens, n=2))
print(dict(bitcoin_bigram.most_common(10)))
# Out:
# {('satoshi', 'nakaboto'): 44, ('char', 'robot'): 22, ('robot', 'colleague'): 22, ('colleague', 'satoshi'): 22, ('nakaboto', 'writes'): 22, ('writes', 'bitcoin'): 22, ('every', 'fucking'): 22, ('fucking', 'daywelcome'): 22, ('daywelcome', 'another'): 22, ('another', 'edition'): 22}

# %%
# Generate the Ethereum N-grams where N=2
ethereum_tokens = []
for list in ethereum_df.tokens:
    ethereum_tokens += list
    
ethereum_bigram = Counter(ngrams(ethereum_tokens, n=2))
print(dict(ethereum_bigram.most_common(10)))
# Out:
# {('char', 'ethereum'): 18, ('decentralized', 'finance'): 12, ('finance', 'defi'): 10, ('ethereum', 'classic'): 10, ('btc', 'trading'): 7, ('trading', 'around'): 7, ('char', 'bitcoin'): 6, ('ethereum', 'miner'): 6, ('ethereum', 'blockchain'): 6, ('around', 'utc'): 5}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(bitcoin_tokens)
# Out:
# [('char', 96),
#  ('bitcoin', 80),
#  ('satoshi', 44),
#  ('nakaboto', 44),
#  ('today', 24),
#  ('every', 23),
#  ('another', 23),
#  ('edition', 23),
#  ('tell', 23),
#  ('going', 23)]

# %%
# Get the top 10 words for Ethereum
token_count(ethereum_tokens)
# Out:
# [('char', 94),
#  ('ethereum', 60),
#  ('ha', 25),
#  ('bitcoin', 23),
#  ('network', 20),
#  ('blockchain', 17),
#  ('defi', 16),
#  ('decentralized', 16),
#  ('cryptocurrency', 13),
#  ('exchange', 13)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
big_string_bitcoin = ' '.join(bitcoin_tokens)
wc = WordCloud().generate(big_string_bitcoin)
plt.axis("off")
plt.title("Bitcoin Word Cloud")
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
big_string_ethereum = ' '.join(ethereum_tokens)
wc = WordCloud().generate(big_string_ethereum)
plt.axis("off")
plt.title("Ethereum Word Cloud")
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bitcoin_text = " ".join(bitcoin_df.text.to_list())

# %%
# Run the NER processor on all of the text
bitcoin_ner = nlp(bitcoin_text)

# Add a title to the document
bitcoin_ner.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Casa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Colorado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based provider of bitcoin security services, is launching a managed service allowing customers to buy and hold their own bitcoin, rather than using an external custodian like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+1571 chars] In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Secret Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  seized
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , NYT reports.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weeks later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bennett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  received a letter explaining that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Secret Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had recovered
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of his Bitcoins. The letter cited… [+884 chars] The question still remained, though, whether all that GPU-crunching would actually work. After
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of hammering on the problem, Stay was finally ready to try. The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Guy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  hadn't given the entire ZIP f… [+2880 chars] A ransomware variant called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NetWalker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is doing surprisingly well, even in this economy. The malware, which takes computers hostage and asks for a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ransom, raked in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $25 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# … [+1606 chars] “The COVID-19 pandemic has resulted in a mass shift to working from home, resulting in increased use of corporate
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VPN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and elimination of in-person verification, which can partially explain the succes… [+3548 chars] In what appears to be a massive coordinated strike against
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reddit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , hackers took
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     over dozens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase;

# %%
# List all Entities
for ent in bitcoin.ents:
    print(ent.text, ent.label_)
# Out:
# Casa ORG
# Colorado GPE
# Coinbas ORG
# April DATE
# the Secret Service ORG
# 100 CARDINAL
# Bitcoins ORG
# Clark GPE
# Weeks later DATE
# Bennett PERSON
# the Secret Service ORG
# 100 CARDINAL
# months DATE
# Guy PERSON
# NetWalker ORG
# Bitcoin GPE
# $25 million MONEY
# the last five DATE
# VPN PRODUCT
# Reddit ORG
# over dozens CARDINAL
# Friday DATE
# afternoon TIME
# pro-Donald Trump PERSON
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# over a year DATE
# Monday DATE
# 2020 DATE
# March DATE
# 4.4% PERCENT
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Wednesday DATE
# 17-year-old DATE
# Florida GPE
# Twitter ORG
# last month DATE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Blockfolio GPE
# FTX ORG
# $150 million MONEY
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# George Ball PERSON
# Sanders Morris Harris ORG
# Bitcoin GPE
# Fred Katayama PERSON
# Reuters ORG
# JPMorgan ORG
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Rick Wilking PERSON
# ul><li PERSON
# Michael Novogratz PERSON
# Bloomberg PERSON
# up to $3,000 MONEY
# The Galaxy Digital ORG
# Fed ORG
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# August DATE
# 17, 2020 DATE
# 6 min QUANTITY
# Tim Draper PERSON
# Draper Fisher Jurvetson ORG
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Grayscale Bitcoin BTC Trust FAC
# GBTC ORG
# Bitcoin GPE
# $1.5 billion MONEY
# this year DATE
# 90% PERCENT
# just six months DATE
# Stanford ORG
# Alexander Liegl PERSON
# Liegl PERSON
# Peter Thiel PERSON
# Bitcoin GPE
# BTC ORG
# two CARDINAL
# UNUS SED LEO ORG
# LEO ORG
# 29.81 MONEY
# August 17 DATE
# 97% PERCENT
# SpaceX CARDINAL
# NASA ORG
# last week DATE
# first ORDINAL
# millions CARDINAL
# YouTube PRODUCT
# Earth LOC
# Tens of thousands CARDINAL
# August 6 DATE
# Overnight TIME
# Bitcoin GPE
# Front Page Tech WORK_OF_ART
# 100,000 CARDINAL
# this week DATE
# first ORDINAL
# YouTube PRODUCT
# US GPE
# Mac PERSON
# Xcode ORG
# Trend Micro ORG
# Last week DATE
# YouTube PRODUCT
# Bitcoin GPE
# Joe Sullivan PERSON
# U.S. GPE
# the United States District Court GPE
# the Northern District LOC
# Richard Stallman PERSON
# Cointelegraph ORG
# Elon Musk ORG
# Tesla ORDINAL
# Thursday DATE
# Russian NORP
# Bitfinex PERSON
# $400 million MONEY
# $1.33 billion MONEY
# Bitcoin BTCstolen FAC
# 2016 DATE
# Bitfinex PERSON
# Sept 2 DATE
# Reuters ORG
# 300 billion tenge MONEY
# $714 million MONEY
# Digital Development ORG
# Bagdat Mussin PERSON
# Wedn PERSON
# Lincolnshire GPE
# two CARDINAL
# three CARDINAL
# two CARDINAL
# Tesco ORG
# Nigel Wright PERSON
# Market Rasen PERSON
# Reuters ORG
# Binance ORG
# the Delta Summit EVENT
# Malta GPE
# Blockchain ORG
# Digital Innovation ORG
# Ta' GPE
# Qali WORK_OF_ART
# MSTR PERSON
# today DATE
# Graham Ivan Clark PERSON
# 17 DATE
# Twitter ORG
# Florida GPE
# last months DATE
# Twitterbitcoin DATE
# Reuters ORG
# 17-year-old DATE
# Florida GPE
# Twitter Inc ORG
# Democratic NORP
# Joe Biden PERSON
# Reuters ORG
# 17-year-old DATE
# Florida GPE
# Twitter Inc ORG
# Democratic NORP
# Joe Biden PERSON
# WASHINGTON GPE
# Reuters ORG
# Uber Technologies ORG
# Thursday DATE
# 2016 DATE
# about 57 mi CARDINAL
# Reuters ORG
# U.S. GPE
# Thursday DATE
# 280 CARDINAL
# North Korean NORP
# millions of dollars MONEY
# two CARDINAL
# Reuters ORG
# U.S. GPE
# Thursday DATE
# 280 CARDINAL
# North Korean NORP
# millions of dollars MONEY
# two CARDINAL
# Twitter ORG
# Android app PERSON
# Android PERSON
# 2018 DATE
# Mike Stay PERSON
# 300,000 MONEY
# bitcoin GPE
# July DATE
# three CARDINAL
# US GPE
# UK GPE
# Sullivan PERSON
# up to eight years DATE
# Knibbeler PERSON
# 'Current Studies' WORK_OF_ART
# 2013-2016 DATE
# 16-year-old DATE
# Massachusetts GPE
# July DATE
# Twitter ORG
# July DATE
# 17-year-old DATE
# Graham Clark PERSON
# WASHINGTON GPE
# Reuters ORG
# The U.S. Justice Department ORG
# Thursday DATE
# Hamas ORG
# al Qaeda ORG
# Islamic State ORG
# 17-year-old DATE
# Graham Ivan Clark PERSON
# 30 CARDINAL
# Twitter ORG
# dozens CARDINAL
# over $10 MONEY
# TNW Basics ORG
# Gmail PERSON
# HONG KONG/NEW YORK GPE
# Reuters ORG
# Asian NORP
# Tuesday DATE
# Sino NORP
# Square Inc. ORG
# Wednesday DATE
# the second quarter DATE
# a day DATE
# Baltimore GPE
# Dominic DiPietro PERSON
# the past few years DATE
# the past few years DATE
# just one CARDINAL
# the past few years DATE
# Jeff Royder PERSON
# Acct Mgr PERSON
# Michael Scott PERSON
# Join Meeting ORG
# Zoom PERSON
# five CARDINAL
# one CARDINAL
# the past few years DATE
# the past few years DATE
# the past few years DATE
# just one CARDINAL
# just one CARDINAL
# Andrew Kelly PERSON
# 10 QUANTITY
# the Opening Bell ORG
# every morning TIME
# 1 CARDINAL
# Bryan Connor Herrell PERSON
# 11 years DATE
# US GPE
# Depa PERSON
# the wee hours of the morning TIME
# John Wick PERSON
# Twitter ORG
# Indian NORP
# Narendra Modis PERSON
# one CARDINAL
# ul><li PERSON
# US NORP
# May 2018 DATE
# Tuesday DATE
# five days DATE
# August DATE
# 3 CARDINAL
# 2020 DATE
# 3 CARDINAL
# MagThe PRODUCT
# Twitter PERSON
# Florida GPE
# 17-year-old DATE
# Friday DATE
# the Justice Department ORG
# Graham Clark PERSON
# 17-year-old DATE
# Florida GPE
# Twitter ORG
# Tuesday DATE
# Democratic NORP
# Zoom NORP
# Graham Clark PERSON
# 17 DATE
# Twitter ORG
# this morning TIME
# Zoombombers PERSON
# weekly DATE
# Pardon The Intrusion ORG
# TNWs bi-weekly PERSON
# LONDON GPE
# Reuters ORG
# about 20% PERCENT
# Asian NORP
# 0.24% PERCENT
# Chinese NORP
# 0.18% PERCENT
# Buffet GPE
# the day DATE
# 9to5Mac CARDINAL
# 9to5Mac CARDINAL
# Daily DATE
# Stitcher PERSON
# TuneIn CARDINAL
# Google Play PRODUCT
# RSS ORG
# the day DATE
# 9to5Mac CARDINAL
# 9to5Mac CARDINAL
# Daily DATE
# Stitcher PERSON
# TuneIn CARDINAL
# Google Play PRODUCT
# RSS ORG
# House ORG
# Nancy Pelosi PERSON
# D-CA ORG
# 174 CARDINAL
# House ORG
# Democrats NORP
# Donald Trump's PERSON
# Postmaster General ORG
# Brain Worms PERSON
# today DATE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ethereum_text = " ".join(ethereum_df.text.to_list())

# %%
# Run the NER processor on all of the text
ethereum_ner = nlp(ethereum_text)

# Add a title to the document
ethereum_ner.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(ethereum_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">If you've interacted with cryptocurrencies in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past couple of years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , there's a good chance you've used MetaMask. It's a cryptocurrency wallet in the form of a browser extension that supports Ether… [+2291 chars] TL;DR: The Mega Blockchain Mastery Bundle is on sale for £
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.81
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , saving you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# </br>Cash isn't necessarily king anymore. You've probably heard that cryptocurrency and bloc… [+1286 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LONDON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - It sounds like a surefire bet. You lend money to a borrower who puts up collateral that exceeds the size of the loan, and then you earn interest of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 20%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# . What could possibly g… [+7143 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NEW YORK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brooklyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based technology startup
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ConsenSys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has acquired
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JPMorgan Chase &amp;amp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ; Co’s (JPM.N) marquee blockchain platform
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quorum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , the companies said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>As part of the dea… [+1915 chars] An outspoken
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  whale who rarely shows affection for anything other than
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>The pseudonymous trader known as Joe007 says
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNUS SED LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) may be a soli… [+1503 chars] REUTERS/
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick Wilking
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>&lt;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ul&gt;&lt;li
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# &gt;
# <mark cl

# %%
# List all Entities
for ent in ethereum_ner.ents:
    print(ent.text, ent.label_)
# Out:
# the past couple of years DATE
# 29.81 MONEY
# August 17 DATE
# 97% PERCENT
# LONDON GPE
# Reuters ORG
# about 20% PERCENT
# NEW YORK PERSON
# Reuters ORG
# Brooklyn GPE
# ConsenSys ORG
# JPMorgan Chase &amp ORG
# Quorum PRODUCT
# Tuesday DATE
# Bitcoin GPE
# BTC ORG
# two CARDINAL
# UNUS SED LEO ORG
# LEO ORG
# Rick Wilking PERSON
# ul><li PERSON
# Michael Novogratz PERSON
# Bloomberg PERSON
# up to $3,000 MONEY
# The Galaxy Digital ORG
# Fed ORG
# August DATE
# 4 DATE
# 2020 DATE
# 5 CARDINAL
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# first ORDINAL
# second ORDINAL
# one CARDINAL
# bitcoin GPE
# more than 10% PERCENT
# 24-hour TIME
# Ethereum ORG
# Mateusz Slodkowski/ PERSON
# Bitcoin GPE
# Bitcoin GPE
# as high as $12,086 MONEY
# Ethereum (ETH ORG
# Medalla PERSON
# the Ethereum Foundation ORG
# ul><li PERSON
# Medalla GPE
# Aug. 2 DATE
# 418 MONEY
# 5 minutes TIME
# 25% PERCENT
# Binance Futures ORG
# ETH ORG
# as low as $302 MONEY
# 385 MONEY
# 10 minutes TIME
# one hundred dollar MONEY
# Fintech ORG
# Last week DATE
# YouTube PRODUCT
# Bitcoin GPE
# Bitcoin GPE
# one-week DATE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,595 MONEY
# 20:0 CARDINAL
# Creator Coin PERSON
# Creator Coin PERSON
# Monday DATE
# 500 CARDINAL
# less than 1% PERCENT
# 3 p.m. EDT TIME
# Ho PERSON
# Bitcoin GPE
# Tuesday DATE
# DeFi ORG
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,2587 as of 20:00 MONEY
# 4 p.m. ET TIME
# 1.6% PERCENT
# DeFi ORG
# this weekend DATE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,579 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 2.4% PERCENT
# Silicon Valley LOC
# cLabs ORG
# DeFi ORG
# Mondays DATE
# $7 million MONEY
# the past month DATE
# ul><li GPE
# Bitcoin GPE
# BTC ORG
# around $12,00 MONEY
# Ethereum ( ORG
# Ethereum Classic ORG
# late last week DATE
# another 51% PERCENT
# early Thursday TIME
# morning TIME
# Bitcoin GPE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,298 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 3.8% PERCENT
# second ORDINAL
# three weeks DATE
# ul><li PERSON
# Tuesday DATE
# WarGames ORG
# 1983 DATE
# Matthew Broderick PERSON
# U.S. GPE
# DeFi ORG
# Geth PERSON
# 27 months DATE
# daily DATE
# 3 p.m. Eastern TIME
# Apple Podcasts, Spo WORK_OF_ART
# Matic Network ORG
# $5 million MONEY
# DeFi ORG
# ul><li PERSON
# Ma PERSON
# Ethereum Classic PRODUCT
# Instagram PRODUCT
# Bitmain GPE
# Blockchain Bites WORK_OF_ART
# second ORDINAL
# nearly a quarter DATE
# the Tor Network ORG
# Bitcoin GPE
# Twitter ORG
# Friday DATE
# DisclosureThe ORG
# CoinDesk PRODUCT
# Tether PERSON
# Tether PERSON
# DEFI ORG
# INX ORG
# 1 billion CARDINAL
# Tron to Ethereum ORG
# bitcoin GPE
# Blockchai GPE
# Baseline Protocol PERSON
# Version 1.0 PRODUCT
# Wednesday DATE
# Micr PERSON
# JPMorgan Chase ORG
# ConsenSys ORG
# Brooklyn GPE
# JPMorgan ORG
# un ORG
# DeFi ORG
# DeFi Pulse PERSON
# 1.47 MONEY
# last month DATE
# the U.S. Office of the Comptroller of the Currency ORG
# OCC ORG
# Bitcoin GPE
# Wednesday DATE
# DeFi ORG
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,396 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 4.8% PERCENT
# the previous 24 hours TIME
# One CARDINAL
# 2020 DATE
# DeFi ORG
# July DATE
# DG Lab ORG
# 13% PERCENT
# First ORDINAL
# May and June DATE
# GitHub ORG
# DeFi PERSON
# approximately $5.6 million MONEY
# Ethereum Classic GPE
# ETC ORG
# two CARDINAL
# 51% PERCENT
# Protocol PRODUCT
# Polkadot ORG
# weeks DATE
# today DATE
# developer house Snowfork ORG
# Chainlink ORG
# Arbol ORG
# Arbol ORG
# a Verifiable Delay Function ORG
# VDF ORG
# a second 51% PERCENT
# a week DATE
# Thursday DATE
# morning TIME
# more than 4,000 CARDINAL
# Ethereum Classics ORG
# January DATE
# two CARDINAL
# 51% PERCENT
# August DATE
# Bitcoin GPE
# BTC ORG
# Monday DATE
# 2020 CARDINAL
# above $12,400 MONEY
# Ethereum Classic FAC
# Blockchain Bites WORK_OF_ART
# daily DATE
# as many as 15 CARDINAL
# OMG Network ORG
# the past week DATE
# CoinGecko ORG
# Leah Callon-Butler PERSON
# Emfarsis ORG
# Asia LOC
# the early 1980s DATE
# zero CARDINAL
# years DATE
# USDT ORG
# U.S. GPE
# bitcoin rises GPE
# Dot ORG
# Ouriel Ohayon PERSON
# 2017 DATE
# Ava Labs ORG
# Cornel PERSON
# Hedget PERSON
# 500,000 MONEY
# ul><li PERSON
# Monday DATE
# FBG Capital ORG
# NGC Ventures ORG
# Asia LOC
# Litecoin Litecoin PERSON
# Charlie Lee PERSON
# The Litecoin Network ORG
# every 2.5 minutes TIME
# Bitcoin GPE
# 10 m CARDINAL
# 3.58% PERCENT
# Monday DATE
# Sundays DATE
# 10.93% PERCENT
# the day DATE
# 3.0463 MONEY
# the day DATE
# early morning TIME
# low $2.9022 MONEY
# bef PERSON
# Ethereum ORG
# Tuesday DATE
# DeFi ORG
# Crypto ORG
# Grayscale ORG
# Ethereum Trust ORG
# Securities and Exchange Commission ORG
# SEC ORG
# Thursday DATE
# $143.8 million MONEY
# July DATE
# 23-month DATE
# The Block Research ORG
# nearly 23% PERCENT
# The Ethereum Classic ORG
# ETC ORG
# a second 51% PERCENT
# a week DATE
# Ethermine ORG
# Thursday DATE
# morning TIME
# Yahoo ORG
# de Verizon PERSON
# Cliquez ORG
# sur J'accepte PRODUCT
# Verizon Media PRODUCT
# Ethereum Classic ORG
# 51% PERCENT
# Saturday DATE
# evening TIME
# third ORDINAL
# 51% PERCENT
# this month DATE
# Bitfly ORG
# first ORDINAL
# Aug. 1 DATE
# ul><li PERSON
# Ethereum 2.0 ORG
# ETH ORG
# Fall 2020 DATE
# 5-10% PERCENT
# RenVM DeFi GPE
# more than 100% PERCENT
# the past week DATE
# RenVM GPE
# 10,000 CARDINAL
# Bitcoin GPE
# BTC-USD ORG
# ETH-USD ORG
# 7.77% PERCENT
# Tuesday DATE
# 1.99% PERCENT
# Monday DATE
# the day DATE
# 3.1234 MONEY
# the day DATE
# early morning TIME
# 3.3961 MONEY
# $1 billion MONEY
# 2017 DATE
# 4.11% PERCENT
# Sunday DATE
# 14% PERCENT
# Saturday DATE
# the week DATE
# 28.09% PERCENT
# 3.8792 MONEY
# the day DATE
# early morning TIME
# 3.8724 MONEY
# Litecoin Litecoin PERSON
# Charlie Lee PERSON
# The Litecoin Network ORG
# every 2.5 minutes TIME
# Bitcoin GPE
# 10 m CARDINAL
# Signature Bank ORG
# dozens CARDINAL
# Ethereum Classic ORG
# another 51% PERCENT
# CryptoSafe Alliance ORG
# Oasis Labs ORG
# ul><li PERSON
# Mongolian NORP
# Venezuela GPE
# 13% PERCENT
# one CARDINAL
# Digital ORG
# Ethereum Classic ORG
# Wednesday DATE
# 51% PERCENT
# recent weeks DATE
# Ethereum Classic PRODUCT
# Mongolian NORP
# Venezuela GPE
# 13% PERCENT
# Tether PERSON
# today DATE
# 1 billion USDT MONEY
# 8% PERCENT
# TRON ORG
# Tether PERSON
# Paolo Ardoino PERSON
# DeFi PERSON
# The Block Research ORG
# second ORDINAL
# 51% PERCENT
# Thursday DATE
# 4,236 CARDINAL
# $1.68 million MONEY
# bitcoin GPE
# 12 MONEY
# CoinDesk’s Markets Daily ORG
# Ap PERSON
# EBON PERSON
# Friday DATE
# DeFi ORG
# Acala PERSON
# DeFi LOC
# Polkadot LOC
# $7 million MONEY
# Bitcoin GPE
# Tuesday DATE
# DeFi ORG
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,2587 as of 20:00 MONEY
# 4 p.m. ET TIME
# 1.6% PERCENT

# %% [markdown]
# ---
